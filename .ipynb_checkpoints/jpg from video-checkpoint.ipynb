# %%
import numpy as np
import cv2, os, random,shutil

# %% [markdown]
# Необходимо
# заполнить параметры в следующей ячейке
# и запустить последовательно ячейки ниже

# %%
#На входе нам нужны:
#1. Структура видео:
#- Путь к видео файлу 1, имя класса 1, нужен ли поворот (применяется, если видео надо развернуть, если 0 то не нужен)
#- Путь к видео файлу 2, имя класса 2, нужен ли поворот (если 0 то не нужен)
#- Путь к видео файлу N, имя класса N, нужен ли поворот (если 0 то не нужен)
_VIDEO =  [
    ["/Users/alexeyvaganov/doc/files/foto_mp/video/mam_short.mp4","mam",0],
    ["/Users/alexeyvaganov/doc/files/foto_mp/video/pap_short.mp4","pap",0]
]

#2.Путь к папке в которой будут созданы файлы
OUT_FOLDER = "/Users/alexeyvaganov/doc/files/foto_mp/files"

#3.На сколько процентов уменьшить фото (если не надо уменьшать поставить 100)
scale_percent = 50
#4.Надо ли проводить аугментацию
AUG = False
#5 Процент файлов Validation
_VALID = 20
#6 Процент файлов Test
_TEST = 10

# %% [markdown]
# # Процедуры и функции

# %%
# Основные процедуры преобразования
def start_video_to_frame():
    
    # создадим папки
    mk_dir_(os.path.join(OUT_FOLDER, "train"))
    mk_dir_(os.path.join(OUT_FOLDER, "validation"))
    mk_dir_(os.path.join(OUT_FOLDER, "test"))
    
    # создадим папки меток
    for i in _VIDEO:
        mk_dir_(os.path.join(OUT_FOLDER, "train/%s" %i[1] ))
        mk_dir_(os.path.join(OUT_FOLDER, "validation/%s" %i[1] ))
        mk_dir_(os.path.join(OUT_FOLDER, "test/%s" %i[1] ))
        
    # сначала все нарезаем в папку train
    index_video = 1
    for i in _VIDEO:
        # получили видео
        convert_video = i[0]
        # папка куда выгружаем
        dir_out = os.path.join(OUT_FOLDER, "train/%s" %i[1])
        # префикс складывеется из префика признака и порядкового номера
        prefix = i[1]+str(index_video)
        # признак необходимости перевернуть видео
        rotate = i[2]
        print("Start convert to ", convert_video,dir_out,prefix,rotate)
        # вызывыаем обработку видео
        video_to_frames(convert_video,dir_out,prefix,rotate)

    # а после того как все нарежем часть случайных файлов перенесем в остальные папки
    # получим пути к папкам
    dir_train = os.path.join(OUT_FOLDER, "train")
    dir_validation = os.path.join(OUT_FOLDER, "validation")
    dir_test = os.path.join(OUT_FOLDER, "test")
    # список папок в папке train
    dir_in_train = os.listdir(dir_train)
    for dir_prizn in dir_in_train:
        # путь к папке с признаками в папке train
        path_dir_prizn = os.path.join(dir_train, dir_prizn)
        # проврим, что это действительно папка 
        if os.path.isdir(path_dir_prizn):
            # полуим список файлов
            files = os.listdir(path_dir_prizn)
            # перемешаем их
            random.shuffle(files)
            # найдем количество файлов
            kol_files = len(files)
            # сколько пойдет в валидацию
            num_val = kol_files // 100 * _VALID
            # сколько пойдет в train
            num_test = kol_files // 100 * _TEST
            # массив со списком файлов для валидации
            files_val = files[0:num_val]
            # массив для списка файлов для теста
            files_test = files[num_val + 1:num_val + num_test]
            # обойдем все файлы из массива валидации
            for fv in files_val:
                # и скопируем файлы
                shutil.move(os.path.join(path_dir_prizn, fv),os.path.join(dir_validation, dir_prizn))

            # обойдем все файлы из массива test
            for fv in files_test:
                # и скопируем файлы
                shutil.move(os.path.join(path_dir_prizn, fv),os.path.join(dir_test, dir_prizn))
               
# функции нарезки фото из видео
def video_to_frames(video, dir_out, prefix,rotate):
    # extract frames from a video and save to directory as 'x.jpg' where 
    # x is the frame index
    #video = cv2.VideoCapture('/Users/alexeyvaganov/doc/files/foto_mp/pap.mov')
    vidcap = cv2.VideoCapture(video)
    count = 0
    while vidcap.isOpened():
        success, image = vidcap.read()
        if success:
            img_name = 'img_%s_%d.jpg' % (prefix,count)
            img_path = os.path.join(dir_out, img_name)
            image = autocrop(image, threshold=0)
            cv2.imwrite(img_path,image) 
            print("Start convert image ", img_path)
            #convert_image(img_path,rotate)
            if AUG:
                augmentation(dir_out,img_name)
            count += 1
        else:
            break
    # print(count)
    cv2.destroyAllWindows()
    vidcap.release()
    
# конвертировать картинку   
def convert_image(image_path,rotate): 
    
    image = cv2.imread(image_path)
    

    width = int(image.shape[1] * scale_percent / 100)
    height = int(image.shape[0] * scale_percent / 100)
    
    dim = (width, height)
    image = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
    
    # и тут же перевренем
    if rotate != 0:
        image = rotate_bound(image, rotate)

    cv2.imwrite(image_path, image) 

# Повернуть картинку. параметры: картинка, угол
def rotate_bound(image, angle): 
    # grab the dimensions of the image and then determine the
    # center
    (h, w) = image.shape[:2]
    (cX, cY) = (w // 2, h // 2)
    # grab the rotation matrix (applying the negative of the
    # angle to rotate clockwise), then grab the sine and cosine
    # (i.e., the rotation components of the matrix)
    M = cv2.getRotationMatrix2D((cX, cY), -angle, 1.0)
    cos = np.abs(M[0, 0])
    sin = np.abs(M[0, 1])
    # compute the new bounding dimensions of the image
    nW = int((h * sin) + (w * cos))
    nH = int((h * cos) + (w * sin))
    # adjust the rotation matrix to take into account translation
    M[0, 2] += (nW / 2) - cX
    M[1, 2] += (nH / 2) - cY
    # perform the actual rotation and return the image

    return cv2.warpAffine(image, M, (nW, nH)) 

def autocrop(image, threshold=0):
    if len(image.shape) == 3:
        flatImage = np.max(image, 2)
    else:
        flatImage = image
    assert len(flatImage.shape) == 2

    rows = np.where(np.max(flatImage, 0) > threshold)[0]
    if rows.size:
        cols = np.where(np.max(flatImage, 1) > threshold)[0]
        image = image[cols[0]: cols[-1] + 1, rows[0]: rows[-1] + 1]
    else:
        image = image[:1, :1]
    
    return image

# создание папки
def mk_dir_ (path):
    if os.path.isdir(path):
        print ("Папка %s существует" %path )
    else:
        os.mkdir(path)
        print ("Создана папка %s " %path )

# функции аугментацию
def augmentation(dir_out,img_name):
    
    img_name_ws = img_name.replace(".jpg","_")
    
    img = cv2.imread(os.path.join(dir_out, img_name))

    
    img_aug = rotation(img,30)
    cv2.imwrite(os.path.join(dir_out,img_name_ws + "r+.jpg"),img_aug)
    
    img_aug = rotation(img,-30)
    cv2.imwrite(os.path.join(dir_out,img_name_ws + "r-.jpg"),img_aug)
    
    img_aug = vertical_flip(img, True)
    cv2.imwrite(os.path.join(dir_out,img_name_ws + "v.jpg"),img_aug)
    
    img_aug = horizontal_flip(img, True)
    cv2.imwrite(os.path.join(dir_out,img_name_ws + "t.jpg"),img_aug)
    
    img_aug = channel_shift(img, 50)
    cv2.imwrite(os.path.join(dir_out,img_name_ws + "c.jpg"),img_aug)
    
    img_aug = zoom(img, 0.2)
    cv2.imwrite(os.path.join(dir_out,img_name_ws + "z2.jpg"),img_aug)
    
    img_aug = zoom(img, 0.3)
    cv2.imwrite(os.path.join(dir_out,img_name_ws + "z3.jpg"),img_aug)
    
    img_aug = brightness(img, 0.5, 3)
    cv2.imwrite(os.path.join(dir_out,img_name_ws + "b.jpg"),img_aug)
    
    img_aug = vertical_shift(img, 0.7)
    cv2.imwrite(os.path.join(dir_out,img_name_ws + "vs.jpg"),img_aug)
    
    img_aug = horizontal_shift(img, ratio=0.7)
    cv2.imwrite(os.path.join(dir_out,img_name_ws + "gs.jpg"),img_aug)

# %%
# вспомогательные функции для аугментации
# https://towardsdatascience.com/complete-image-augmentation-in-opencv-31a6b02694f5

# горизонтальное смещение
def horizontal_shift(img, ratio=0.0):
    if ratio > 1 or ratio < 0:
        print('Value should be less than 1 and greater than 0')
        return img
    ratio = random.uniform(-ratio, ratio)
    h, w = img.shape[:2]
    to_shift = w*ratio
    if ratio > 0:
        img = img[:, :int(w-to_shift), :]
    if ratio < 0:
        img = img[:, int(-1*to_shift):, :]
    img = fill(img, w, h)
    return img

# вертикальное смещение
def vertical_shift(img, ratio=0.0):
    if ratio > 1 or ratio < 0:
        print('Value should be less than 1 and greater than 0')
        return img
    ratio = random.uniform(-ratio, ratio)
    h, w = img.shape[:2]
    to_shift = h*ratio
    if ratio > 0:
        img = img[:int(h-to_shift), :, :]
    if ratio < 0:
        img = img[int(-1*to_shift):, :, :]
    img = fill(img, w, h)
    return img

# яркость
def brightness(img, low, high):
    value = random.uniform(low, high)
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    hsv = np.array(hsv, dtype = np.float64)
    hsv[:,:,1] = hsv[:,:,1]*value
    hsv[:,:,1][hsv[:,:,1]>255]  = 255
    hsv[:,:,2] = hsv[:,:,2]*value 
    hsv[:,:,2][hsv[:,:,2]>255]  = 255
    hsv = np.array(hsv, dtype = np.uint8)
    img = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    return img

# вспомогательная
def fill(img, h, w):
    img = cv2.resize(img, (h, w), cv2.INTER_CUBIC)
    return img

# зумиррование
def zoom(img, value):
    if value > 1 or value < 0:
        print('Value for zoom should be less than 1 and greater than 0')
        return img
    value = random.uniform(value, 1)
    h, w = img.shape[:2]
    h_taken = int(value*h)
    w_taken = int(value*w)
    h_start = random.randint(0, h-h_taken)
    w_start = random.randint(0, w-w_taken)
    img = img[h_start:h_start+h_taken, w_start:w_start+w_taken, :]
    img = fill(img, w, h)
    return img

# смещение канала
def channel_shift(img, value):
    value = int(random.uniform(-value, value))
    img = img + value
    img[:,:,:][img[:,:,:]>255]  = 255
    img[:,:,:][img[:,:,:]<0]  = 0
    img = img.astype(np.uint8)
    return img

# горизонтальное отображение
def horizontal_flip(img, flag):
    if flag:
        return cv2.flip(img, 1)
    else:
        return img

# вертикальное отображение
def vertical_flip(img, flag):
    if flag:
        return cv2.flip(img, 0)
    else:
        return img

#  сдвиг
def rotation(img, angle):
    angle = int(random.uniform(-angle, angle))
    h, w = img.shape[:2]
    M = cv2.getRotationMatrix2D((int(w/2), int(h/2)), angle, 1)
    img = cv2.warpAffine(img, M, (w, h))
    return img

# %% [markdown]
# # Запуск

# %%
start_video_to_frame()
print("Operation Complet")
# Out:
# Создана папка /Users/alexeyvaganov/doc/files/foto_mp/files/train
# Создана папка /Users/alexeyvaganov/doc/files/foto_mp/files/validation
# Создана папка /Users/alexeyvaganov/doc/files/foto_mp/files/test
# Создана папка /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam
# Создана папка /Users/alexeyvaganov/doc/files/foto_mp/files/validation/mam
# Создана папка /Users/alexeyvaganov/doc/files/foto_mp/files/test/mam
# Создана папка /Users/alexeyvaganov/doc/files/foto_mp/files/train/pap
# Создана папка /Users/alexeyvaganov/doc/files/foto_mp/files/validation/pap
# Создана папка /Users/alexeyvaganov/doc/files/foto_mp/files/test/pap
# Start convert to  /Users/alexeyvaganov/doc/files/foto_mp/video/mam_short.mp4 /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam mam1 0
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_0.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_1.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_2.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_3.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_4.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_5.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_6.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_7.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_8.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_9.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_10.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_11.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_12.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_13.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_14.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_15.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_16.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_17.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_18.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_19.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_20.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_21.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_22.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_23.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_24.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_25.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_26.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_27.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_28.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_29.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_30.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_31.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_32.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_33.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_34.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_35.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_36.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_37.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_38.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_39.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_40.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_41.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_42.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_43.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_44.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_45.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_46.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_47.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_48.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_49.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_50.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_51.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_52.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_53.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_54.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_55.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_56.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_57.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_58.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_59.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_60.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_61.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_62.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_63.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_64.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_65.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_66.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_67.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_68.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_69.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_70.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_71.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_72.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_73.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_74.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_75.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_76.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_77.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_78.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_79.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_80.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_81.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_82.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_83.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_84.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_85.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_86.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_87.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_88.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_89.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_90.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_91.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_92.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_93.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_94.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_95.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_96.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_97.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_98.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_99.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_100.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_101.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_102.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_103.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_104.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_105.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_106.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_107.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_108.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_109.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_110.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_111.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_112.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_113.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_114.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_115.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_116.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_117.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_118.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_119.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_120.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_121.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_122.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_123.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_124.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_125.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_126.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_127.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_128.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_129.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_130.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_131.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_132.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_133.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_134.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_135.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_136.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_137.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_138.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_139.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_140.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_141.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_142.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_143.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_144.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_145.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_146.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_147.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_148.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_149.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_150.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_151.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_152.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_153.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_154.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_155.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_156.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_157.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_158.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_159.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_160.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_161.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_162.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_163.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_164.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_165.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_166.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_167.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_168.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_169.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_170.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_171.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_172.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_173.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_174.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_175.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_176.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_177.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_178.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_179.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_180.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_181.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_182.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_183.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_184.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_185.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_186.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_187.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_188.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_189.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_190.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_191.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_192.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_193.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_194.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_195.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_196.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_197.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_198.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_199.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_200.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_201.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_202.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_203.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_204.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_205.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_206.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_207.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_208.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_209.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_210.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_211.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_212.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_213.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_214.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_215.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_216.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_217.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_218.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_219.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_220.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_221.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_222.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_223.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_224.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_225.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_226.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_227.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_228.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_229.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_230.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_231.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_232.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_233.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_234.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_235.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_236.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_237.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_238.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_239.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_240.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_241.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_242.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_243.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_244.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_245.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_246.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_247.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_248.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_249.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_250.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_251.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_252.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_253.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_254.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_255.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_256.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_257.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_258.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_259.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_260.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_261.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_262.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_263.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_264.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_265.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_266.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_267.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_268.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_269.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_270.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_271.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_272.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_273.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_274.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1_275.jpg
# Start convert image  /Users/alexeyvaganov/doc/files/foto_mp/files/train/mam/img_mam1